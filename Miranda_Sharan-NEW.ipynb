# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)

# %%
xls = pd.ExcelFile('Supplier Lead Times.xlsx')
default_lead = pd.read_excel(xls, 'Default Lead')
stock_lead1 = pd.read_excel(xls, 'Stock Lead')
stock_lead2 = pd.read_excel(xls, 'Sheet4')

# %%
default_lead.shape
# Out:
# (61, 3)

# %%
stock_lead1.shape
# Out:
# (490499, 10)

# %%
stock_lead2.shape
# Out:
# (528518, 10)

# %%
# check and drop duplicates
default_lead.drop_duplicates(inplace = True)

# %%
stock_lead1.duplicated().value_counts()
# Out:
# False    490499
# dtype: int64

# %%
stock_lead2.duplicated().value_counts()
# Out:
# False    528518
# dtype: int64

# %%
default_lead.head()
# Out:
#   Supplier LoadingPort  TotalLeadTime
# 0  JADD010      NINGBO            105
# 1  JBEN020      NINGBO            120
# 2  JBRT010      NINGBO            120
# 3  JCDA010      NINGBO             90
# 4  JRCC010         NaN             30

# %%
stock_lead1.head()
# Out:
#   StockCode Supplier LoadingPort DestinationPort Warehouse  ToSupplierDays  \
# 0    .K6RTC  JTOR020      NINGBO       CAPE TOWN        C2               1
# 1    .K6RTC  JTOR020      NINGBO          DURBAN        B3               1
# 2    .K6RTC  JTOR020      NINGBO          DURBAN        CW               1
# 3    .K6RTC  JTOR020      NINGBO          DURBAN        D1               1
# 4    .K6RTC  JTOR020      NINGBO          DURBAN        J1               1
#
#    FactoryDeliveryDays  VesselDays  ToWarehouseDays  TotalLeadTime
# 0                   90          33                2            126
# 1                   90          24                5            120
# 2                   90          24                5            120
# 3                   90          24                4            119
# 4                   90          24                5            120

# %%
stock_lead2.head()
# Out:
#     StockCode Supplier LoadingPort DestinationPort Warehouse  ToSupplierDays  \
# 0  HD0700FD02  JHON010   KAOHSIUNG       CAPE TOWN        C2               2
# 1  HD0700FD02  JHON010   KAOHSIUNG          DURBAN        B3               2
# 2  HD0700FD02  JHON010   KAOHSIUNG          DURBAN        CW               2
# 3  HD0700FD02  JHON010   KAOHSIUNG          DURBAN        D1               2
# 4  HD0700FD02  JHON010   KAOHSIUNG          DURBAN        J1               2
#
#    FactoryDeliveryDays  VesselDays  ToWarehouseDays  TotalLeadTime
# 0                   45          29                2             78
# 1                   45          24                5             76
# 2                   45          24                5             76
# 3                   45          24                4             75
# 4                   45          24                5             76

# %%
stock_lead1.Warehouse.unique()
# Out:
# array(['C2', 'B3', 'CW', 'D1', 'J1', 'J2', 'J3', 'L2', 'N1', 'P2', 'E1',
#        'EL', 'G1', 'L1'], dtype=object)

# %%
stock_lead2.Warehouse.unique()
# Out:
# array(['C2', 'B3', 'CW', 'D1', 'J1', 'J2', 'J3', 'L2', 'N1', 'P2', 'E1',
#        'EL', 'G1', 'L1'], dtype=object)

# %%
# NO data for J0, A1 warehouses

# %%
# sperate data tables for different warehouses

# %%
C2_stock_lead1 = stock_lead1[stock_lead1.Warehouse == 'C2']
C2_stock_lead2 = stock_lead2[stock_lead2.Warehouse == 'C2']

# %%
C2_stock_lead = pd.concat([C2_stock_lead1,C2_stock_lead2]).reset_index(drop=True)

# %%
C2_stock_lead.shape
# Out:
# (85711, 10)

# %%
J1_stock_lead1 = stock_lead1[stock_lead1.Warehouse == 'J1']
J1_stock_lead2 = stock_lead2[stock_lead2.Warehouse == 'J1']

# %%
J1_stock_lead = pd.concat([J1_stock_lead1,J1_stock_lead2]).reset_index(drop=True)

# %%
J1_stock_lead.shape
# Out:
# (102783, 10)

# %%
J2_stock_lead1 = stock_lead1[stock_lead1.Warehouse == 'J2']
J2_stock_lead2 = stock_lead2[stock_lead2.Warehouse == 'J2']

# %%
J2_stock_lead = pd.concat([J2_stock_lead1,J2_stock_lead2]).reset_index(drop=True)

# %%
J2_stock_lead.shape
# Out:
# (102783, 10)

# %%
J3_stock_lead1 = stock_lead1[stock_lead1.Warehouse == 'J3']
J3_stock_lead2 = stock_lead2[stock_lead2.Warehouse == 'J3']

# %%
J3_stock_lead = pd.concat([J3_stock_lead1,J3_stock_lead2]).reset_index(drop=True)

# %%
J3_stock_lead.shape
# Out:
# (102783, 10)

# %%
C2_sales = pd.read_excel('sale_movements/sales_movements_C2.xlsx')

# %%
def calculate_buffer(sales, stock_lead):
    sales['EntryDate'] = pd.to_datetime(sales['EntryDate'])
    # only keeping StockCode and TotalLeadTime in lead time data
    stock_lead = stock_lead[['StockCode','TotalLeadTime']].reset_index(drop=True)
    # for each unique stock code, calculate the average TotalLeadTime and maximum TotalLeadTime
    _mean = stock_lead.groupby('StockCode')['TotalLeadTime'].mean()
    _max = stock_lead.groupby('StockCode')['TotalLeadTime'].max()
    stock_lead_meanmax = pd.concat([_mean,_max],axis = 1).reset_index()
    stock_lead_meanmax.columns = ['StockCode','MeanTotalLeadTime','MaxTotalLeadTime']
    sales_lead_time = sales.merge(stock_lead_meanmax,on = 'StockCode',how = 'left')
    TrnQty_sum = sales_lead_time[sales_lead_time.TrnQty > 0].groupby('StockCode')['TrnQty'].sum()
    TrnQty_timerange = sales_lead_time[sales_lead_time.TrnQty > 0].groupby(
    'StockCode')['EntryDate'].apply(lambda x: x.iloc[-1] - x.iloc[0])
    TrnQty_max = sales_lead_time[sales_lead_time.TrnQty > 0].groupby('StockCode')['TrnQty'].max()
    stock_TrnQty_meanmax = pd.concat([TrnQty_sum,TrnQty_timerange,TrnQty_max],axis = 1).reset_index()
    stock_TrnQty_meanmax.columns = ['StockCode','SumTrnQty','timerange','MaxTrnQty']
    stock_TrnQty_meanmax.timerange = stock_TrnQty_meanmax.timerange.dt.days
    stock_TrnQty_meanmax['MeanTrnQty'] = stock_TrnQty_meanmax[
        'SumTrnQty'] / stock_TrnQty_meanmax['timerange']
    stock_TrnQty_meanmax.loc[stock_TrnQty_meanmax[
        'MeanTrnQty'] == np.inf,'MeanTrnQty'] = stock_TrnQty_meanmax.SumTrnQty
    
    TrnQty_leadtime = stock_TrnQty_meanmax.merge(stock_lead_meanmax, on='StockCode',how='left')
    TrnQty_leadtime['BufferStock'] = (TrnQty_leadtime.MaxTrnQty * TrnQty_leadtime.MaxTotalLeadTime) - (
    TrnQty_leadtime.MeanTrnQty * TrnQty_leadtime.MeanTotalLeadTime)
    return TrnQty_leadtime

# %%
# max daily usage - not the maximum turn quantity??? that might be an outlier 

# try validate it with items() first and

# try to eliminate the outlier

# recalculate the MEAN and MAX

# %%
def print_metrics(TrnQty_leadtime):
    print("min:", TrnQty_leadtime.BufferStock.min())
    print("25th percentile:", TrnQty_leadtime.BufferStock.quantile(0.25))
    print("median:", TrnQty_leadtime.BufferStock.median())
    print("75th percentile:", TrnQty_leadtime.BufferStock.quantile(0.75))
    print("max:", TrnQty_leadtime.BufferStock.max())

# %%
df = calculate_buffer(C2_sales, C2_stock_lead)

# %%
print_metrics(df)
# Out:
# min: -252.0
# 25th percentile: 1.5
# median: 90.09
# 75th percentile: 189.43830275229357
# max: 16768.59813084112

# %%
df.sort_values('BufferStock',ascending = False).head(50)
# Out:
#             StockCode  SumTrnQty  timerange  MaxTrnQty  MeanTrnQty  \
# 82        12342PROQC1       4392        107        600   41.046729
# 119       12972PROQC1       4115        134        500   30.708955
# 909           3006160       2258         62        500   36.419355
# 5066         HUFD0210        112         86         74    1.302326
# 156   212-11B9L-RD-E2        383        138        100    2.775362
# 910           3009260        910         55        390   16.545455
# 2389            BD518        962        136        100    7.073529
# 3768         CVTO1010       1428        140        100   10.200000
# 5070         HUMZ0040        182        140         40    1.300000
# 1399     442-1945R-UE        292        139         50    2.100719
# 146    212-1140L-RD-E        307        132         50    2.325758
# 3661         CVOP1002        742        140         66    5.300000
# 912           3015373        230         63        190    3.650794
# 2837          BKD9040        140        125         50    1.120000
# 1398     442-1945L-UE        274        139         43    1.971223
# 157   212-11B9R-RD-E2        329        139         43    2.366906
# 3828       CVVW1001ZZ        763        138         50    5.528986
# 604    216-1107L-RD-E        134        133         40    1.007519
# 452      213-1910L-WE        232        135         40    1.718519
# 281      212-15F7R3AE        246        135         40    1.822222
# 280      212-15F7L3AE        247        134         40    1.843284
# 6816         RDVW0240        216        139         50    1.553957
# 3770       CVTO1010ZZ       1290        140         50    9.214286
# 6390           RDCAP9        215        107         50    2.009346
# 6790         RDVW0010        497        140         50    3.550000
# 6705         RDTA0080        765        140         50    5.464286
# 2226           BD2848        128        135         39    0.948148
# 9278        WBFW1499A        204        131         35    1.557252
# 307      212-1662R-AE        297        135         35    2.200000
# 3827         CVVW1001       1048        137         50    7.649635
# 3592       CVMZ1001ZZ        537        140         40    3.835714
# 11         0241235751       3104        137        600   22.656934
# 147    212-1140R-RD-E        318        140         33    2.271429
# 3849         CVVW5004        286        140         40    2.042857
# 6586         RDMZ0040        279        137         40    2.036496
# 5073         HUTA0080        122        139         20    0.877698
# 648      216-1530L-UE        198        137         30    1.445255
# 649      216-1530R-UE        211        136         30    1.551471
# 169   212-11G9L-REMNC         87        123         29    0.707317
# 9290          WBFW216        361        140         30    2.578571
# 225      212-1418N-AE        391        140         30    2.792857
# 9306          WBFW368        429        139         30    3.086331
# 4      00-213-1910L-E        170        126         28    1.349206
# 2075           BD1158        197        132         30    1.492424
# 4837          GHBM720        208        111         31    1.873874
# 4872          GHBS520        119        131         30    0.908397
# 8654       VW0010BP29        128        134         35    0.955224
# 4863         GHBR1920        109        134         29    0.813433
# 4842          GHBN400        255        139         30    1.834532
# 1335   442-1102L-RD-E        113        135         25    0.837037
#
#       MeanTotalLeadTime  MaxTotalLeadTime   BufferStock
# 82            30.000000              30.0  16768.598131
# 119           30.000000              30.0  14078.731343
# 909           30.000000              30.0  13907.419355
# 5066         133.500000             186.0  13590.139535
# 156          125.000000             125.0  12153.079710
# 910           30.000000              30.0  11203.636364
# 2389         114.000000             114.0  10593.617647
# 3768          93.500000              96.0   8646.300000
# 5070         133.500000             186.0   7266.450000
# 1399         125.000000             125.0   5987.410072
# 146          125.000000             125.0   5959.280303
# 3661          93.500000              96.0   5840.450000
# 912           30.000000              30.0   5590.476190
# 2837         114.000000             114.0   5572.320000
# 1398         125.000000             125.0   5128.597122
# 157          125.000000             125.0   5079.136691
# 3828          99.333333             111.0   5000.787440
# 604          125.000000             125.0   4874.060150
# 452          125.000000             125.0   4785.185185
# 281          125.000000             125.0   4772.222222
# 280          125.000000             125.0   4769.589552
# 6816          91.500000              96.0   4657.812950
# 3770          99.333333             111.0   4634.714286
# 6390          96.000000              96.0   4607.102804
# 6790          91.500000              96.0   4475.175000
# 6705          94.000000              99.0   4436.357143
# 2226         114.000000             114.0   4337.911111
# 9278         126.000000             126.0   4213.786260
# 307          125.000000             125.0   4100.000000
# 3827          93.500000              96.0   4084.759124
# 3592          99.333333             111.0   4058.985714
# 11             7.000000               7.0   4041.401460
# 147          125.000000             125.0   3841.071429
# 3849          93.500000              96.0   3648.992857
# 6586          96.000000              96.0   3644.496350
# 5073         133.500000             186.0   3602.827338
# 648          125.000000             125.0   3569.343066
# 649          125.000000             125.0   3556.066176
# 169          125.000000             125.0   3536.585366
# 9290         126.000000             126.0   3455.100000
# 225          125.000000             125.0   3400.892857
# 9306         126.000000             126.0   3391.122302
# 4            125.000000             125.0   3331.349206
# 2075         114.000000             114.0   3249.863636
# 4837         111.000000             111.0   3233.000000
# 4872         111.000000             111.0   3229.167939
# 8654          85.500000              93.0   3173.328358
# 4863         111.000000             111.0   3128.708955
# 4842         111.000000             111.0   3126.366906
# 1335         125.000000             125.0   3020.370370
